# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('../outputs/sim_0.npz')

# Access arrays:
times = data["times"]
A = data["A"]
B = data["B"]
A_MRNA = data["A_MRNA"]
B_MRNA = data["B_MRNA"]
states = data["states"]

plt.figure(figsize=(10, 6))

# Plot mRNA concentrations
#plt.plot(times, A_MRNA, label='CcdA mRNA')
#plt.plot(times, B_MRNA, label='CcdB mRNA')

#Plot protein concentrations
plt.plot(times, A, label='CcdA protein')
plt.plot(times, B, label='CcdB protein')

plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title('CcdA/B mRNA and Protein Concentrations Over Time')
plt.legend()
plt.grid(True)
plt.show()
