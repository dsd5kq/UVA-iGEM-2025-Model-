# %%
import numpy as np
import statistics as st

# Store loaded data in a dictionary
data = {}
times = {}

# Load all data files into the dictionary
for n in range(999):
    data[n] = np.load(f'../outputs/sim_{n}.npz')
    times[n] = data[n]['times']

# Extract last time points into a list
first_pass = [times[z][-1] for z in range(999)]

# Compute average
average = sum(first_pass) / len(first_pass)

std = st.stdev([float(x) for x in first_pass])

print(f"Average first pass time:{average}\u00B1{std}")
print(max(max(t) for t in times.values()))
# Out:
# Average first pass time:32214.431431431432±16012.474473690638
# 95868

# %%
pip install git+https://github.com/opencobra/cobrapy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/opencobra/cobrapy to /tmp/pip-req-build-2s1wup4m
#   Running command git clone --filter=blob:none --quiet https://github.com/opencobra/cobrapy /tmp/pip-req-build-2s1wup4m
#   Resolved https://github.com/opencobra/cobrapy to commit c891dabb84b8d6b9422822921d8f2e7b9dd76edf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 108.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 10.6 MB/s eta 0:00:00
# ...

# %%
pip install git+https://github.com/tibbdc/ECMpy.git@v2.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/tibbdc/ECMpy.git (to revision v2.0.0) to /tmp/pip-req-build-ieq4fpsg
#   Running command git clone --filter=blob:none --quiet https://github.com/tibbdc/ECMpy.git /tmp/pip-req-build-ieq4fpsg
#   Running command git checkout -q 433463a9b22994765351eae1ea1b74d133f7a483
#   Resolved https://github.com/tibbdc/ECMpy.git to commit 433463a9b22994765351eae1ea1b74d133f7a483
# ERROR: git+https://github.com/tibbdc/ECMpy.git@v2.0.0 does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.
